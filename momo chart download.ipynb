# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from mplfinance.original_flavor import candlestick_ohlc
import matplotlib.dates as mdates
import matplotlib.gridspec as gridspec
import os
import time
import random

# Load the Excel sheet with ticker and date information
excel_file = 'C:\\Users\\LENOVO\\OneDrive\\Desktop\\screenshot.xlsx'
df_tickers = pd.read_excel(excel_file, sheet_name='screenshot')  # Adjust sheet name if needed

# Function to fetch OHLC data for a given ticker and date
def fetch_ohlc_data(ticker, start_date, end_date):
    try:
        # Fetch data including Saturdays and Sundays
        stock_data = yf.download(ticker, start=start_date, end=end_date)
        # Filter out Saturdays (5) and Sundays (6)
        stock_data = stock_data[stock_data.index.dayofweek < 5]
        return stock_data
    except Exception as e:
        print(f"Error fetching data for {ticker} on {start_date}: {e}")
        return None

# Function to plot and save OHLC chart with volume bars
def plot_save_ohlc_chart(ticker, date, ohlc_data, output_folder):
    if ohlc_data is None:
        return  # Skip plotting if there was an error fetching data
    
    # Convert date to matplotlib date format
    ohlc_data['Date'] = mdates.date2num(ohlc_data.index)

    # Increase the size of the chart
    fig = plt.figure(figsize=(16, 10))
    fig.patch.set_facecolor('#121212')  # Background color

    # Create a 2x1 grid
    gs = gridspec.GridSpec(2, 1, height_ratios=[4, 1])

    # Plot the candlestick chart in the upper subplot
    ax1 = plt.subplot(gs[0])
    candlestick_ohlc(ax1, ohlc_data[['Date', 'Open', 'High', 'Low', 'Close']].values, width=0.7, colorup='#089981', colordown='#f23645')
    
    # Plot 21-day EMA
    ema_21 = ohlc_data['Close'].ewm(span=21, adjust=False).mean()
    ax1.plot(ohlc_data['Date'], ema_21, label='21 EMA', color='orange', linewidth=1)

    # Format the x-axis to show dates nicely
    ax1.xaxis_date()
    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

    # Rotate x-axis labels for better readability
    plt.setp(ax1.get_xticklabels(), rotation=0)

    # Set labels and title for the upper subplot
    ax1.set_xlabel('Date', color='white')  # White color for X-axis label
    ax1.set_ylabel('Price', color='white')  # White color for Y-axis label
    ax1.set_title(f'OHLC Chart for {ticker} - {date}', color='white')  # White color for title
    ax1.legend()

    # Set grid, dark mode colors, and reduce opacity of gridlines
    ax1.grid(True, linestyle='--', alpha=0.3, color='#555555')  # Reduced opacity for grid lines
    ax1.spines['bottom'].set_color('white')  # White color for X-axis
    ax1.spines['top'].set_color('white')  # White color for X-axis
    ax1.spines['right'].set_color('white')  # White color for Y-axis
    ax1.spines['left'].set_color('white')  # White color for Y-axis
    ax1.tick_params(axis='both', colors='white')  # White color for ticks

    # Create the lower subplot for volume bars
    ax2 = plt.subplot(gs[1], sharex=ax1)
    
    # Plot volume bars as columns
    ax2.bar(ohlc_data['Date'], ohlc_data['Volume'], color='black', alpha=1, width=0.7)

    # Set labels and title for the lower subplot
    ax2.set_xlabel('Date', color='white')  # White color for X-axis label
    ax2.set_ylabel('Volume', color='white')  # White color for Y-axis label
    ax2.tick_params(axis='both', colors='white')  # White color for ticks
    
    # Highlight the candlestick of the initial input date
    initial_date_index = ohlc_data.index.get_loc(date)
    ax1.axvline(x=ohlc_data['Date'][initial_date_index], color='orange', linestyle='solid', linewidth=5, alpha=0.1, label='Initial Date')
    
    try:
        # Save the plot as a PNG file with formatted date information in the filename
        formatted_date = date.strftime('%Y-%m-%d_%H-%M-%S')
        output_file = f'{output_folder}/{ticker}_{formatted_date}_ohlc_chart.png'
        fig.savefig(output_file, bbox_inches='tight')
        plt.close()
    except OSError as e:
        print(f"Error saving file for {ticker} on {date}: {e}")
    except Exception as e:
        print(f"Unexpected error: {e}")

# Specify the output folder
output_folder = 'output_charts'

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Loop through each row in the DataFrame
for index, row in df_tickers.iterrows():
    ticker = row['Ticker']
    date = row['Date']

    # Fetch OHLC data for 60 days before and after the specified date
    start_date = pd.to_datetime(date) - pd.DateOffset(days=60)
    end_date = pd.to_datetime(date) + pd.DateOffset(days=90)
    
    print(f"Fetching data for {ticker} on {date}...")
    
    # Introduce a random delay between 1 and 4 seconds
    delay = random.uniform(1, 4)
    time.sleep(delay)
    
    # Plot and save OHLC chart with volume bars
    ohlc_data = fetch_ohlc_data(ticker, start_date, end_date)
    if ohlc_data is not None:
        print(f"Data fetched successfully for {ticker} on {date}.")
        plot_save_ohlc_chart(ticker, date, ohlc_data, output_folder)
    else:
        print(f"Skipping {ticker} on {date} due to data fetch error.")

print('OHLC charts with volume bars have been generated and saved in the output folder.')
# Out:
# Fetching data for ORBTEXP.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ORBTEXP.NS on 2022-02-01 00:00:00.
# Fetching data for MMTC.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MMTC.NS on 2022-02-01 00:00:00.
# Fetching data for AMBICAAGAR.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AMBICAAGAR.NS on 2022-02-01 00:00:00.
# Fetching data for WANBURY.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for WANBURY.NS on 2022-02-01 00:00:00.
# Fetching data for PSPPROJECT.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PSPPROJECT.NS on 2022-02-01 00:00:00.
# Fetching data for BRNL.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BRNL.NS on 2022-02-01 00:00:00.
# Fetching data for ZODIAC.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ZODIAC.NS on 2022-02-01 00:00:00.
# Fetching data for ORIENTBELL.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ORIENTBELL.NS on 2022-02-01 00:00:00.
# Fetching data for CHEMFAB.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for CHEMFAB.NS on 2022-02-01 00:00:00.
# Fetching data for DSSL.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DSSL.NS on 2022-02-01 00:00:00.
# Fetching data for CANBK.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for CANBK.NS on 2022-02-01 00:00:00.
# Fetching data for GPIL.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for GPIL.NS on 2022-02-01 00:00:00.
# Fetching data for EMKAY.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for EMKAY.NS on 2022-02-01 00:00:00.
# Fetching data for PFOCUS.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PFOCUS.NS on 2022-02-01 00:00:00.
# Fetching data for IRB.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for IRB.NS on 2022-02-01 00:00:00.
# Fetching data for LOTUSEYE.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for LOTUSEYE.NS on 2022-02-01 00:00:00.
# Fetching data for GRAVITA.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for GRAVITA.NS on 2022-02-01 00:00:00.
# Fetching data for SHARDACROP.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SHARDACROP.NS on 2022-02-01 00:00:00.
# Fetching data for SHYAMCENT.NS on 2022-02-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SHYAMCENT.NS on 2022-02-01 00:00:00.
# Fetching data for MADRASFERT.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MADRASFERT.NS on 2022-04-01 00:00:00.
# Fetching data for BIRLACORPN.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BIRLACORPN.NS on 2022-04-01 00:00:00.
# Fetching data for CENTRUM.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for CENTRUM.NS on 2022-04-01 00:00:00.
# Fetching data for VAKRANGEE.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for VAKRANGEE.NS on 2022-04-01 00:00:00.
# Fetching data for AWL.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AWL.NS on 2022-04-01 00:00:00.
# Fetching data for MANINDS.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MANINDS.NS on 2022-04-01 00:00:00.
# Fetching data for SIMPLEXINF.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SIMPLEXINF.NS on 2022-04-01 00:00:00.
# Fetching data for ELGIRUBCO.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ELGIRUBCO.NS on 2022-04-01 00:00:00.
# Fetching data for ARTNIRMAN.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ARTNIRMAN.NS on 2022-04-01 00:00:00.
# Fetching data for SHANTI.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SHANTI.NS on 2022-04-01 00:00:00.
# Fetching data for AXISCADES.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AXISCADES.NS on 2022-04-01 00:00:00.
# Fetching data for TVSELECT.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TVSELECT.NS on 2022-04-01 00:00:00.
# Fetching data for DEEPINDS.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DEEPINDS.NS on 2022-04-01 00:00:00.
# Fetching data for SHIVAMAUTO.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SHIVAMAUTO.NS on 2022-04-01 00:00:00.
# Fetching data for ADANIPOWER.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ADANIPOWER.NS on 2022-04-01 00:00:00.
# Fetching data for SANSERA.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SANSERA.NS on 2022-04-01 00:00:00.
# Fetching data for BIGBLOC.NS on 2022-04-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BIGBLOC.NS on 2022-04-01 00:00:00.
# Fetching data for BANCOINDIA.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BANCOINDIA.NS on 2022-06-01 00:00:00.
# Fetching data for JINDALPOLY.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for JINDALPOLY.NS on 2022-06-01 00:00:00.
# Fetching data for RAYMOND.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RAYMOND.NS on 2022-06-01 00:00:00.
# Fetching data for VERANDA.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for VERANDA.NS on 2022-06-01 00:00:00.
# Fetching data for PITTIENG.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PITTIENG.NS on 2022-06-01 00:00:00.
# Fetching data for HBLPOWER.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for HBLPOWER.NS on 2022-06-01 00:00:00.
# Fetching data for TIMKEN.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TIMKEN.NS on 2022-06-01 00:00:00.
# Fetching data for POLYPLEX.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for POLYPLEX.NS on 2022-06-01 00:00:00.
# Fetching data for MIRZAINT.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MIRZAINT.NS on 2022-06-01 00:00:00.
# Fetching data for DOLLAR.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DOLLAR.NS on 2022-06-01 00:00:00.
# Fetching data for STERTOOLS.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for STERTOOLS.NS on 2022-06-01 00:00:00.
# Fetching data for ROUTE.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ROUTE.NS on 2022-06-01 00:00:00.
# Fetching data for MANGALAM.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MANGALAM.NS on 2022-06-01 00:00:00.
# Fetching data for RENUKA.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RENUKA.NS on 2022-06-01 00:00:00.
# Fetching data for AIAENG.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AIAENG.NS on 2022-06-01 00:00:00.
# Fetching data for EKC.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for EKC.NS on 2022-06-01 00:00:00.
# Fetching data for NAUKRI.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for NAUKRI.NS on 2022-06-01 00:00:00.
# Fetching data for AMDIND.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AMDIND.NS on 2022-06-01 00:00:00.
# Fetching data for MANAKSIA.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MANAKSIA.NS on 2022-06-01 00:00:00.
# Fetching data for ZENTEC.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ZENTEC.NS on 2022-06-01 00:00:00.
# Fetching data for PGEL.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PGEL.NS on 2022-06-01 00:00:00.
# Fetching data for RTNINDIA.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RTNINDIA.NS on 2022-06-01 00:00:00.
# Fetching data for AWHCL.NS on 2022-06-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AWHCL.NS on 2022-06-01 00:00:00.
# Fetching data for SHALPAINTS.NS on 2022-07-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SHALPAINTS.NS on 2022-07-01 00:00:00.
# Fetching data for RAJRATAN.NS on 2022-07-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RAJRATAN.NS on 2022-07-01 00:00:00.
# Fetching data for BRNL.NS on 2022-07-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BRNL.NS on 2022-07-01 00:00:00.
# Fetching data for GLOBAL.NS on 2022-07-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for GLOBAL.NS on 2022-07-01 00:00:00.
# Fetching data for TPLPLASTEH.NS on 2022-07-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TPLPLASTEH.NS on 2022-07-01 00:00:00.
# Fetching data for ORIENTBELL.NS on 2022-07-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ORIENTBELL.NS on 2022-07-01 00:00:00.
# Fetching data for PRITI.NS on 2022-07-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PRITI.NS on 2022-07-01 00:00:00.
# Fetching data for RUCHIRA.NS on 2022-07-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RUCHIRA.NS on 2022-07-01 00:00:00.
# Fetching data for HUBTOWN.NS on 2022-07-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for HUBTOWN.NS on 2022-07-01 00:00:00.
# Fetching data for YAARI.NS on 2022-07-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for YAARI.NS on 2022-07-01 00:00:00.
# Fetching data for IMAGICAA.NS on 2022-07-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for IMAGICAA.NS on 2022-07-01 00:00:00.
# Fetching data for WSTCSTPAPR.NS on 2022-08-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for WSTCSTPAPR.NS on 2022-08-01 00:00:00.
# Fetching data for EMUDHRA.NS on 2022-08-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for EMUDHRA.NS on 2022-08-01 00:00:00.
# Fetching data for ARCHIDPLY.NS on 2022-08-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ARCHIDPLY.NS on 2022-08-01 00:00:00.
# Fetching data for KECL.NS on 2022-08-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for KECL.NS on 2022-08-01 00:00:00.
# Fetching data for YAARI.NS on 2022-08-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for YAARI.NS on 2022-08-01 00:00:00.
# Fetching data for METROBRAND.NS on 2022-08-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for METROBRAND.NS on 2022-08-01 00:00:00.
# Fetching data for IMAGICAA.NS on 2022-08-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for IMAGICAA.NS on 2022-08-01 00:00:00.
# Fetching data for BEARDSELL.NS on 2022-08-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BEARDSELL.NS on 2022-08-01 00:00:00.
# Fetching data for SURYAROSNI.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SURYAROSNI.NS on 2022-09-01 00:00:00.
# Fetching data for RELINFRA.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RELINFRA.NS on 2022-09-01 00:00:00.
# Fetching data for NELCO.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for NELCO.NS on 2022-09-01 00:00:00.
# Fetching data for SAKHTISUG.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SAKHTISUG.NS on 2022-09-01 00:00:00.
# Fetching data for WALCHANNAG.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for WALCHANNAG.NS on 2022-09-01 00:00:00.
# Fetching data for RAMRAT.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RAMRAT.NS on 2022-09-01 00:00:00.
# Fetching data for DCMSRIND.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DCMSRIND.NS on 2022-09-01 00:00:00.
# Fetching data for VINYLINDIA.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for VINYLINDIA.NS on 2022-09-01 00:00:00.
# Fetching data for TEJASNET.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TEJASNET.NS on 2022-09-01 00:00:00.
# Fetching data for CLEDUCATE.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for CLEDUCATE.NS on 2022-09-01 00:00:00.
# Fetching data for GLOBAL.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for GLOBAL.NS on 2022-09-01 00:00:00.
# Fetching data for TOTAL.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TOTAL.NS on 2022-09-01 00:00:00.
# Fetching data for 5PAISA.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for 5PAISA.NS on 2022-09-01 00:00:00.
# Fetching data for ICEMAKE.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ICEMAKE.NS on 2022-09-01 00:00:00.
# Fetching data for DHRUV.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DHRUV.NS on 2022-09-01 00:00:00.
# Fetching data for PARACABLES.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PARACABLES.NS on 2022-09-01 00:00:00.
# Fetching data for AHLADA.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AHLADA.NS on 2022-09-01 00:00:00.
# Fetching data for KRITIKA.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for KRITIKA.NS on 2022-09-01 00:00:00.
# Fetching data for POLYMED.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for POLYMED.NS on 2022-09-01 00:00:00.
# Fetching data for MAZDOCK.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MAZDOCK.NS on 2022-09-01 00:00:00.
# Fetching data for LIKHITHA.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for LIKHITHA.NS on 2022-09-01 00:00:00.
# Fetching data for TTML.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TTML.NS on 2022-09-01 00:00:00.
# Fetching data for NDTV.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for NDTV.NS on 2022-09-01 00:00:00.
# Fetching data for LOKESHMACH.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for LOKESHMACH.NS on 2022-09-01 00:00:00.
# Fetching data for KAMDHENU.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for KAMDHENU.NS on 2022-09-01 00:00:00.
# Fetching data for ATLANTAA.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ATLANTAA.NS on 2022-09-01 00:00:00.
# Fetching data for RPOWER.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RPOWER.NS on 2022-09-01 00:00:00.
# Fetching data for SOMICONVEY.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SOMICONVEY.NS on 2022-09-01 00:00:00.
# Fetching data for DLINKINDIA.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DLINKINDIA.NS on 2022-09-01 00:00:00.
# Fetching data for DBREALTY.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DBREALTY.NS on 2022-09-01 00:00:00.
# Fetching data for EROSMEDIA.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for EROSMEDIA.NS on 2022-09-01 00:00:00.
# Fetching data for RAMKY.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RAMKY.NS on 2022-09-01 00:00:00.
# Fetching data for DATAPATTNS.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DATAPATTNS.NS on 2022-09-01 00:00:00.
# Fetching data for BEARDSELL.NS on 2022-09-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BEARDSELL.NS on 2022-09-01 00:00:00.
# Fetching data for OILCOUNTUB.NS on 2022-11-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for OILCOUNTUB.NS on 2022-11-01 00:00:00.
# Fetching data for WEIZMANIND.NS on 2022-11-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for WEIZMANIND.NS on 2022-11-01 00:00:00.
# Fetching data for VINYLINDIA.NS on 2022-11-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for VINYLINDIA.NS on 2022-11-01 00:00:00.
# Fetching data for BIOFILCHEM.NS on 2022-11-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BIOFILCHEM.NS on 2022-11-01 00:00:00.
# Fetching data for TFCILTD.NS on 2022-11-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TFCILTD.NS on 2022-11-01 00:00:00.
# Fetching data for MEDICO.NS on 2022-11-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MEDICO.NS on 2022-11-01 00:00:00.
# Fetching data for KSHITIJPOL.NS on 2022-11-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for KSHITIJPOL.NS on 2022-11-01 00:00:00.
# Fetching data for BANKINDIA.NS on 2022-11-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BANKINDIA.NS on 2022-11-01 00:00:00.
# Fetching data for SPLIL.NS on 2022-11-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SPLIL.NS on 2022-11-01 00:00:00.
# Fetching data for KECL.NS on 2022-11-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for KECL.NS on 2022-11-01 00:00:00.
# Fetching data for TREEHOUSE.NS on 2022-11-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TREEHOUSE.NS on 2022-11-01 00:00:00.
# Fetching data for SIKKO.NS on 2022-11-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SIKKO.NS on 2022-11-01 00:00:00.
# Fetching data for RAMASTEEL.NS on 2022-11-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RAMASTEEL.NS on 2022-11-01 00:00:00.
# Fetching data for PDMJEPAPER.NS on 2022-11-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PDMJEPAPER.NS on 2022-11-01 00:00:00.
# Fetching data for SUULD.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SUULD.NS on 2022-12-01 00:00:00.
# Fetching data for DCM.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DCM.NS on 2022-12-01 00:00:00.
# Fetching data for COSMOFIRST.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for COSMOFIRST.NS on 2022-12-01 00:00:00.
# Fetching data for RICOAUTO.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RICOAUTO.NS on 2022-12-01 00:00:00.
# Fetching data for MARALOVER.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MARALOVER.NS on 2022-12-01 00:00:00.
# Fetching data for SALASAR.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SALASAR.NS on 2022-12-01 00:00:00.
# Fetching data for FOCUS.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for FOCUS.NS on 2022-12-01 00:00:00.
# Fetching data for SUMIT.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SUMIT.NS on 2022-12-01 00:00:00.
# Fetching data for AXITA.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AXITA.NS on 2022-12-01 00:00:00.
# Fetching data for MSTCLTD.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MSTCLTD.NS on 2022-12-01 00:00:00.
# Fetching data for PFOCUS.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PFOCUS.NS on 2022-12-01 00:00:00.
# Fetching data for NETWORK18.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for NETWORK18.NS on 2022-12-01 00:00:00.
# Fetching data for HUBTOWN.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for HUBTOWN.NS on 2022-12-01 00:00:00.
# Fetching data for REFEX.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for REFEX.NS on 2022-12-01 00:00:00.
# Fetching data for MEP.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MEP.NS on 2022-12-01 00:00:00.
# Fetching data for RADHIKAJWE.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RADHIKAJWE.NS on 2022-12-01 00:00:00.
# Fetching data for HPL.NS on 2022-12-01 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for HPL.NS on 2022-12-01 00:00:00.
# Fetching data for KARURVYSYA.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for KARURVYSYA.NS on 2022-02-02 00:00:00.
# Fetching data for DEEPAKFERT.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DEEPAKFERT.NS on 2022-02-02 00:00:00.
# Fetching data for VIPIND.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for VIPIND.NS on 2022-02-02 00:00:00.
# Fetching data for JINDRILL.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for JINDRILL.NS on 2022-02-02 00:00:00.
# Fetching data for ARIHANTCAP.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ARIHANTCAP.NS on 2022-02-02 00:00:00.
# Fetching data for ORBTEXP.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ORBTEXP.NS on 2022-02-02 00:00:00.
# Fetching data for DREDGECORP.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DREDGECORP.NS on 2022-02-02 00:00:00.
# Fetching data for WANBURY.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for WANBURY.NS on 2022-02-02 00:00:00.
# Fetching data for BRNL.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BRNL.NS on 2022-02-02 00:00:00.
# Fetching data for ORIENTBELL.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ORIENTBELL.NS on 2022-02-02 00:00:00.
# Fetching data for CHEMFAB.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for CHEMFAB.NS on 2022-02-02 00:00:00.
# Fetching data for PANACEABIO.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PANACEABIO.NS on 2022-02-02 00:00:00.
# Fetching data for BLBLIMITED.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BLBLIMITED.NS on 2022-02-02 00:00:00.
# Fetching data for DSSL.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DSSL.NS on 2022-02-02 00:00:00.
# Fetching data for CANBK.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for CANBK.NS on 2022-02-02 00:00:00.
# Fetching data for EMKAY.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for EMKAY.NS on 2022-02-02 00:00:00.
# Fetching data for PFOCUS.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PFOCUS.NS on 2022-02-02 00:00:00.
# Fetching data for TV18BRDCST.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TV18BRDCST.NS on 2022-02-02 00:00:00.
# Fetching data for INDIANB.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for INDIANB.NS on 2022-02-02 00:00:00.
# Fetching data for TRIL.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TRIL.NS on 2022-02-02 00:00:00.
# Fetching data for IRB.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for IRB.NS on 2022-02-02 00:00:00.
# Fetching data for LOTUSEYE.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for LOTUSEYE.NS on 2022-02-02 00:00:00.
# Fetching data for GRAVITA.NS on 2022-02-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for GRAVITA.NS on 2022-02-02 00:00:00.
# Fetching data for BIRLACABLE.NS on 2022-03-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BIRLACABLE.NS on 2022-03-02 00:00:00.
# Fetching data for MBAPL.NS on 2022-03-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MBAPL.NS on 2022-03-02 00:00:00.
# Fetching data for MCL.NS on 2022-03-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MCL.NS on 2022-03-02 00:00:00.
# Fetching data for VAISHALI.NS on 2022-03-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for VAISHALI.NS on 2022-03-02 00:00:00.
# Fetching data for ORIENTBELL.NS on 2022-03-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ORIENTBELL.NS on 2022-03-02 00:00:00.
# Fetching data for DSSL.NS on 2022-03-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DSSL.NS on 2022-03-02 00:00:00.
# Fetching data for MAANALU.NS on 2022-03-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MAANALU.NS on 2022-03-02 00:00:00.
# Fetching data for YAARI.NS on 2022-03-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for YAARI.NS on 2022-03-02 00:00:00.
# Fetching data for DUCON.NS on 2022-03-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DUCON.NS on 2022-03-02 00:00:00.
# Fetching data for EQUIPPP.NS on 2022-05-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for EQUIPPP.NS on 2022-05-02 00:00:00.
# Fetching data for MRPL.NS on 2022-05-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MRPL.NS on 2022-05-02 00:00:00.
# Fetching data for CHENNPETRO.NS on 2022-05-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for CHENNPETRO.NS on 2022-05-02 00:00:00.
# Fetching data for RIIL.NS on 2022-05-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RIIL.NS on 2022-05-02 00:00:00.
# Fetching data for JITFINFRA.NS on 2022-05-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for JITFINFRA.NS on 2022-05-02 00:00:00.
# Fetching data for AGROPHOS.NS on 2022-05-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AGROPHOS.NS on 2022-05-02 00:00:00.
# Fetching data for AKG.NS on 2022-05-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AKG.NS on 2022-05-02 00:00:00.
# Fetching data for GOKEX.NS on 2022-05-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for GOKEX.NS on 2022-05-02 00:00:00.
# Fetching data for MANAKSTEEL.NS on 2022-05-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MANAKSTEEL.NS on 2022-05-02 00:00:00.
# Fetching data for MEP.NS on 2022-05-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MEP.NS on 2022-05-02 00:00:00.
# Fetching data for GOKULAGRO.NS on 2022-05-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for GOKULAGRO.NS on 2022-05-02 00:00:00.
# Fetching data for BANCOINDIA.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BANCOINDIA.NS on 2022-06-02 00:00:00.
# Fetching data for CENTURYTEX.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for CENTURYTEX.NS on 2022-06-02 00:00:00.
# Fetching data for JINDALPOLY.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for JINDALPOLY.NS on 2022-06-02 00:00:00.
# Fetching data for RAYMOND.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RAYMOND.NS on 2022-06-02 00:00:00.
# Fetching data for ELECON.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ELECON.NS on 2022-06-02 00:00:00.
# Fetching data for ARSHIYA.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ARSHIYA.NS on 2022-06-02 00:00:00.
# Fetching data for STYRENIX.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for STYRENIX.NS on 2022-06-02 00:00:00.
# Fetching data for VERANDA.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for VERANDA.NS on 2022-06-02 00:00:00.
# Fetching data for SANGAMIND.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SANGAMIND.NS on 2022-06-02 00:00:00.
# Fetching data for TIMKEN.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TIMKEN.NS on 2022-06-02 00:00:00.
# Fetching data for MIRZAINT.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MIRZAINT.NS on 2022-06-02 00:00:00.
# Fetching data for DOLLAR.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DOLLAR.NS on 2022-06-02 00:00:00.
# Fetching data for FINEORG.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for FINEORG.NS on 2022-06-02 00:00:00.
# Fetching data for STERTOOLS.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for STERTOOLS.NS on 2022-06-02 00:00:00.
# Fetching data for ROUTE.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ROUTE.NS on 2022-06-02 00:00:00.
# Fetching data for IZMO.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for IZMO.NS on 2022-06-02 00:00:00.
# Fetching data for MANGALAM.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MANGALAM.NS on 2022-06-02 00:00:00.
# Fetching data for RENUKA.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RENUKA.NS on 2022-06-02 00:00:00.
# Fetching data for EKC.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for EKC.NS on 2022-06-02 00:00:00.
# Fetching data for AMDIND.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AMDIND.NS on 2022-06-02 00:00:00.
# Fetching data for MANAKSIA.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MANAKSIA.NS on 2022-06-02 00:00:00.
# Fetching data for ZENTEC.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ZENTEC.NS on 2022-06-02 00:00:00.
# Fetching data for PGEL.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PGEL.NS on 2022-06-02 00:00:00.
# Fetching data for RTNINDIA.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RTNINDIA.NS on 2022-06-02 00:00:00.
# Fetching data for AWHCL.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AWHCL.NS on 2022-06-02 00:00:00.
# Fetching data for SJS.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SJS.NS on 2022-06-02 00:00:00.
# Fetching data for MONTECARLO.NS on 2022-06-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MONTECARLO.NS on 2022-06-02 00:00:00.
# Fetching data for KANSAINER.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for KANSAINER.NS on 2022-08-02 00:00:00.
# Fetching data for GFLLIMITED.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for GFLLIMITED.NS on 2022-08-02 00:00:00.
# Fetching data for RAIN.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RAIN.NS on 2022-08-02 00:00:00.
# Fetching data for WSTCSTPAPR.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for WSTCSTPAPR.NS on 2022-08-02 00:00:00.
# Fetching data for DEEPAKFERT.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DEEPAKFERT.NS on 2022-08-02 00:00:00.
# Fetching data for GMMPFAUDLR.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for GMMPFAUDLR.NS on 2022-08-02 00:00:00.
# Fetching data for ORBTEXP.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ORBTEXP.NS on 2022-08-02 00:00:00.
# Fetching data for BDL.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BDL.NS on 2022-08-02 00:00:00.
# Fetching data for ANMOL.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ANMOL.NS on 2022-08-02 00:00:00.
# Fetching data for AGARIND.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AGARIND.NS on 2022-08-02 00:00:00.
# Fetching data for TRIL.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TRIL.NS on 2022-08-02 00:00:00.
# Fetching data for DHANI.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DHANI.NS on 2022-08-02 00:00:00.
# Fetching data for NAZARA.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for NAZARA.NS on 2022-08-02 00:00:00.
# Fetching data for IBULHSGFIN.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for IBULHSGFIN.NS on 2022-08-02 00:00:00.
# Fetching data for ZOMATO.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ZOMATO.NS on 2022-08-02 00:00:00.
# Fetching data for SIKKO.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SIKKO.NS on 2022-08-02 00:00:00.
# Fetching data for METROBRAND.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for METROBRAND.NS on 2022-08-02 00:00:00.
# Fetching data for IDFCFIRSTB.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for IDFCFIRSTB.NS on 2022-08-02 00:00:00.
# Fetching data for BEARDSELL.NS on 2022-08-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BEARDSELL.NS on 2022-08-02 00:00:00.
# Fetching data for SURYAROSNI.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SURYAROSNI.NS on 2022-09-02 00:00:00.
# Fetching data for RELINFRA.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RELINFRA.NS on 2022-09-02 00:00:00.
# Fetching data for NELCO.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for NELCO.NS on 2022-09-02 00:00:00.
# Fetching data for SAKHTISUG.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SAKHTISUG.NS on 2022-09-02 00:00:00.
# Fetching data for WALCHANNAG.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for WALCHANNAG.NS on 2022-09-02 00:00:00.
# Fetching data for RAMRAT.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RAMRAT.NS on 2022-09-02 00:00:00.
# Fetching data for VINYLINDIA.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for VINYLINDIA.NS on 2022-09-02 00:00:00.
# Fetching data for TEJASNET.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TEJASNET.NS on 2022-09-02 00:00:00.
# Fetching data for AGROPHOS.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AGROPHOS.NS on 2022-09-02 00:00:00.
# Fetching data for GLOBAL.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for GLOBAL.NS on 2022-09-02 00:00:00.
# Fetching data for ICEMAKE.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ICEMAKE.NS on 2022-09-02 00:00:00.
# Fetching data for SHIVAMILLS.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SHIVAMILLS.NS on 2022-09-02 00:00:00.
# Fetching data for CHEMFAB.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for CHEMFAB.NS on 2022-09-02 00:00:00.
# Fetching data for PARACABLES.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PARACABLES.NS on 2022-09-02 00:00:00.
# Fetching data for AARON.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AARON.NS on 2022-09-02 00:00:00.
# Fetching data for MARSHALL.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MARSHALL.NS on 2022-09-02 00:00:00.
# Fetching data for KRITIKA.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for KRITIKA.NS on 2022-09-02 00:00:00.
# Fetching data for POLYMED.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for POLYMED.NS on 2022-09-02 00:00:00.
# Fetching data for MAZDOCK.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MAZDOCK.NS on 2022-09-02 00:00:00.
# Fetching data for LIKHITHA.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for LIKHITHA.NS on 2022-09-02 00:00:00.
# Fetching data for TTML.NS on 2022-09-02 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TTML.NS on 2022-09-02 00:00:00.
# Fetching data for NDTV.NS on 2022-09-02 00:00:00...
# ...
# Data fetched successfully for ATULAUTO.NS on 2022-04-07 00:00:00.
# Fetching data for WELCORP.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for WELCORP.NS on 2022-04-07 00:00:00.
# Fetching data for VAIBHAVGBL.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for VAIBHAVGBL.NS on 2022-04-07 00:00:00.
# Fetching data for SUBEXLTD.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SUBEXLTD.NS on 2022-04-07 00:00:00.
# Fetching data for RAMCOSYS.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RAMCOSYS.NS on 2022-04-07 00:00:00.
# Fetching data for PNC.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PNC.NS on 2022-04-07 00:00:00.
# Fetching data for 3IINFOLTD.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for 3IINFOLTD.NS on 2022-04-07 00:00:00.
# Fetching data for RENUKA.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RENUKA.NS on 2022-04-07 00:00:00.
# Fetching data for KMSUGAR.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for KMSUGAR.NS on 2022-04-07 00:00:00.
# Fetching data for SADBHAV.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SADBHAV.NS on 2022-04-07 00:00:00.
# Fetching data for LOKESHMACH.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for LOKESHMACH.NS on 2022-04-07 00:00:00.
# Fetching data for DCBBANK.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DCBBANK.NS on 2022-04-07 00:00:00.
# Fetching data for AMDIND.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AMDIND.NS on 2022-04-07 00:00:00.
# Fetching data for TIMETECHNO.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TIMETECHNO.NS on 2022-04-07 00:00:00.
# Fetching data for ADSL.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ADSL.NS on 2022-04-07 00:00:00.
# Fetching data for CORDSCABLE.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for CORDSCABLE.NS on 2022-04-07 00:00:00.
# Fetching data for ONMOBILE.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ONMOBILE.NS on 2022-04-07 00:00:00.
# Fetching data for JAIBALAJI.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for JAIBALAJI.NS on 2022-04-07 00:00:00.
# Fetching data for 20MICRONS.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for 20MICRONS.NS on 2022-04-07 00:00:00.
# Fetching data for ADANIPOWER.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ADANIPOWER.NS on 2022-04-07 00:00:00.
# Fetching data for EMMBI.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for EMMBI.NS on 2022-04-07 00:00:00.
# Fetching data for KCPSUGIND.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for KCPSUGIND.NS on 2022-04-07 00:00:00.
# Fetching data for EMAMIREAL.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for EMAMIREAL.NS on 2022-04-07 00:00:00.
# Fetching data for GPPL.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for GPPL.NS on 2022-04-07 00:00:00.
# Fetching data for SURANASOL.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SURANASOL.NS on 2022-04-07 00:00:00.
# Fetching data for OMKARCHEM.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for OMKARCHEM.NS on 2022-04-07 00:00:00.
# Fetching data for BROOKS.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BROOKS.NS on 2022-04-07 00:00:00.
# Fetching data for RVHL.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RVHL.NS on 2022-04-07 00:00:00.
# Fetching data for BECTORFOOD.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BECTORFOOD.NS on 2022-04-07 00:00:00.
# Fetching data for DUCON.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DUCON.NS on 2022-04-07 00:00:00.
# Fetching data for PROZONER.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PROZONER.NS on 2022-04-07 00:00:00.
# Fetching data for ZUARI.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ZUARI.NS on 2022-04-07 00:00:00.
# Fetching data for RAILTEL.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RAILTEL.NS on 2022-04-07 00:00:00.
# Fetching data for EASEMYTRIP.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for EASEMYTRIP.NS on 2022-04-07 00:00:00.
# Fetching data for SURYODAY.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SURYODAY.NS on 2022-04-07 00:00:00.
# Fetching data for VINEETLAB.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for VINEETLAB.NS on 2022-04-07 00:00:00.
# Fetching data for FINOPB.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for FINOPB.NS on 2022-04-07 00:00:00.
# Fetching data for ORTINLAB.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ORTINLAB.NS on 2022-04-07 00:00:00.
# Fetching data for UJJIVAN.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for UJJIVAN.NS on 2022-04-07 00:00:00.
# Fetching data for DBL.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for DBL.NS on 2022-04-07 00:00:00.
# Fetching data for BIGBLOC.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BIGBLOC.NS on 2022-04-07 00:00:00.
# Fetching data for BLS.NS on 2022-04-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BLS.NS on 2022-04-07 00:00:00.
# Fetching data for MRPL.NS on 2022-06-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MRPL.NS on 2022-06-07 00:00:00.
# Fetching data for CHENNPETRO.NS on 2022-06-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for CHENNPETRO.NS on 2022-06-07 00:00:00.
# Fetching data for SUULD.NS on 2022-06-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SUULD.NS on 2022-06-07 00:00:00.
# Fetching data for HINDMOTORS.NS on 2022-06-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for HINDMOTORS.NS on 2022-06-07 00:00:00.
# Fetching data for ELECON.NS on 2022-06-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ELECON.NS on 2022-06-07 00:00:00.
# Fetching data for GLOBAL.NS on 2022-06-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for GLOBAL.NS on 2022-06-07 00:00:00.
# Fetching data for AIRAN.NS on 2022-06-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AIRAN.NS on 2022-06-07 00:00:00.
# Fetching data for FSC.NS on 2022-06-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for FSC.NS on 2022-06-07 00:00:00.
# Fetching data for MANGCHEFER.NS on 2022-06-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MANGCHEFER.NS on 2022-06-07 00:00:00.
# Fetching data for SIL.NS on 2022-06-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SIL.NS on 2022-06-07 00:00:00.
# Fetching data for AAKASH.NS on 2022-06-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AAKASH.NS on 2022-06-07 00:00:00.
# Fetching data for NDTV.NS on 2022-06-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for NDTV.NS on 2022-06-07 00:00:00.
# Fetching data for OIL.NS on 2022-06-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for OIL.NS on 2022-06-07 00:00:00.
# Fetching data for HSCL.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for HSCL.NS on 2022-07-07 00:00:00.
# Fetching data for SPMLINFRA.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SPMLINFRA.NS on 2022-07-07 00:00:00.
# Fetching data for CEATLTD.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for CEATLTD.NS on 2022-07-07 00:00:00.
# Fetching data for AUTOAXLES.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AUTOAXLES.NS on 2022-07-07 00:00:00.
# Fetching data for RESPONIND.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for RESPONIND.NS on 2022-07-07 00:00:00.
# Fetching data for ALEMBICLTD.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for ALEMBICLTD.NS on 2022-07-07 00:00:00.
# Fetching data for AJMERA.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AJMERA.NS on 2022-07-07 00:00:00.
# Fetching data for JAYNECOIND.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for JAYNECOIND.NS on 2022-07-07 00:00:00.
# Fetching data for LASA.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for LASA.NS on 2022-07-07 00:00:00.
# Fetching data for TPLPLASTEH.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TPLPLASTEH.NS on 2022-07-07 00:00:00.
# Fetching data for BCG.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BCG.NS on 2022-07-07 00:00:00.
# Fetching data for PAR.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PAR.NS on 2022-07-07 00:00:00.
# Fetching data for TIPSINDLTD.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for TIPSINDLTD.NS on 2022-07-07 00:00:00.
# Fetching data for STEELXIND.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for STEELXIND.NS on 2022-07-07 00:00:00.
# Fetching data for PCJEWELLER.NS on 2022-07-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PCJEWELLER.NS on 2022-07-07 00:00:00.
# Fetching data for BIRLACABLE.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for BIRLACABLE.NS on 2022-09-07 00:00:00.
# Fetching data for EIHOTEL.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for EIHOTEL.NS on 2022-09-07 00:00:00.
# Fetching data for SAKHTISUG.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SAKHTISUG.NS on 2022-09-07 00:00:00.
# Fetching data for VAKRANGEE.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for VAKRANGEE.NS on 2022-09-07 00:00:00.
# Fetching data for JAICORPLTD.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for JAICORPLTD.NS on 2022-09-07 00:00:00.
# Fetching data for VINYLINDIA.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for VINYLINDIA.NS on 2022-09-07 00:00:00.
# Fetching data for CUBEXTUB.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for CUBEXTUB.NS on 2022-09-07 00:00:00.
# Fetching data for VERTOZ.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for VERTOZ.NS on 2022-09-07 00:00:00.
# Fetching data for PRAXIS.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for PRAXIS.NS on 2022-09-07 00:00:00.
# Fetching data for SHIVAMILLS.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for SHIVAMILLS.NS on 2022-09-07 00:00:00.
# Fetching data for MACPOWER.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MACPOWER.NS on 2022-09-07 00:00:00.
# Fetching data for GOODLUCK.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for GOODLUCK.NS on 2022-09-07 00:00:00.
# Fetching data for MARSHALL.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for MARSHALL.NS on 2022-09-07 00:00:00.
# Fetching data for AKG.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for AKG.NS on 2022-09-07 00:00:00.
# Fetching data for KRITIKA.NS on 2022-09-07 00:00:00...
# [*********************100%%**********************]  1 of 1 completed
# Data fetched successfully for KRITIKA.NS on 2022-09-07 00:00:00.
